# %%
import requests
import json

# %%
from pprint import pprint

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
from flask import Flask, jsonify

# %%
import requests

# %%
url = "https://www.speedrun.com/api/v1/runs"

# %%
response = requests.get(url)
print(response.url)
# Out:
# https://www.speedrun.com/api/v1/runs

# %%
runs_data = response.json()
pprint(runs_data)
# Out:
# {'data': [{'category': 'prklq2n9',
#            'comment': 'bad RNG on frigate otherwise pretty solid',
#            'date': '2013-06-10',
#            'game': 'nj1ne1p4',
#            'id': '1wzpqgyq',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/1wzpqgyq'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'},
#                      {'rel': 'region',
#                       'uri': 'https://www.speedrun.com/api/v1/regions/pr184lqn'}],
#            'players': [{'id': 'v48grxpr',
#                         'rel': 'user',
#                         'uri': 'https://www.speedrun.com/api/v1/users/v48grxpr'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': 'pr184lqn'},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT21M52S',
#                      'primary_t': 1312,
#                      'realtime': 'PT21M52S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1312},
#            'values': {},
#            'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=KKjPMD0aHaY'}]},
#            'weblink': 'https://www.speedrun.com/ge/run/1wzpqgyq'},
#           {'category': 'prklq2n9',
#            'comment': None,
#            'date': None,
#            'game': 'nj1ne1p4',
#            'id': 'opydqjmn',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/opydqjmn'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'},
#                      {'rel': 'region',
#                       'uri': 'https://www.speedrun.com/api/v1/regions/e6lxy1dz'}],
#            'players': [{'id': 'kv813xp5',
#                         'rel': 'user',
#                         'uri': 'https://www.speedrun.com/api/v1/users/kv813xp5'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': 'e6lxy1dz'},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT22M',
#                      'primary_t': 1320,
#                      'realtime': 'PT22M',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1320},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/opydqjmn'},
#           {'category': 'prklq2n9',
#            'comment': None,
#            'date': '2014-02-13',
#            'game': 'nj1ne1p4',
#            'id': 'onz139me',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/onz139me'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'id': '3qjo7x6z',
#                         'rel': 'user',
#                         'uri': 'https://www.speedrun.com/api/v1/users/3qjo7x6z'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT22M28S',
#                      'primary_t': 1348,
#                      'realtime': 'PT22M28S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1348},
#            'values': {},
#            'videos': {'links': [{'uri': 'http://www.twitch.tv/illudude/c/3717856'}]},
#            'weblink': 'https://www.speedrun.com/ge/run/onz139me'},
#           {'category': 'prklq2n9',
#            'comment': '\r',
#            'date': '2012-11-05',
#            'game': 'nj1ne1p4',
#            'id': 'pemk41y6',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/pemk41y6'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'id': 'wdx378lo',
#                         'rel': 'user',
#                         'uri': 'https://www.speedrun.com/api/v1/users/wdx378lo'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT22M45S',
#                      'primary_t': 1365,
#                      'realtime': 'PT22M45S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1365},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/pemk41y6'},
#           {'category': 'prklq2n9',
#            'comment': '\r',
#            'date': '2004-07-02',
#            'game': 'nj1ne1p4',
#            'id': 'ekz5onyr',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/ekz5onyr'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'name': 'Boss',
#                         'rel': 'guest',
#                         'uri': 'https://www.speedrun.com/api/v1/guests/Boss'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT23M7S',
#                      'primary_t': 1387,
#                      'realtime': 'PT23M7S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1387},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/ekz5onyr'},
#           {'category': 'prklq2n9',
#            'comment': '\r',
#            'date': '2005-07-13',
#            'game': 'nj1ne1p4',
#            'id': 'jpm3d4z0',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/jpm3d4z0'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'name': 'Cervone',
#                         'rel': 'guest',
#                         'uri': 'https://www.speedrun.com/api/v1/guests/Cervone'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT23M14S',
#                      'primary_t': 1394,
#                      'realtime': 'PT23M14S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1394},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/jpm3d4z0'},
#           {'category': 'prklq2n9',
#            'comment': 'was sub 23 pace and I had some slow parts that cost me '
#                       'i think.',
#            'date': '2013-12-07',
#            'game': 'nj1ne1p4',
#            'id': 'qdy45dml',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/qdy45dml'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'id': '98rkldx1',
#                         'rel': 'user',
#                         'uri': 'https://www.speedrun.com/api/v1/users/98rkldx1'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT23M25S',
#                      'primary_t': 1405,
#                      'realtime': 'PT23M25S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1405},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/qdy45dml'},
#           {'category': 'prklq2n9',
#            'comment': '\r',
#            'date': None,
#            'game': 'nj1ne1p4',
#            'id': 'voy2q9yd',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/voy2q9yd'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'name': 'Jimbo',
#                         'rel': 'guest',
#                         'uri': 'https://www.speedrun.com/api/v1/guests/Jimbo'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT23M45S',
#                      'primary_t': 1425,
#                      'realtime': 'PT23M45S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1425},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/voy2q9yd'},
#           {'category': 'prklq2n9',
#            'comment': '\r',
#            'date': None,
#            'game': 'nj1ne1p4',
#            'id': 'x7z03ez5',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/x7z03ez5'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'name': 'Trent',
#                         'rel': 'guest',
#                         'uri': 'https://www.speedrun.com/api/v1/guests/Trent'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT23M58S',
#                      'primary_t': 1438,
#                      'realtime': 'PT23M58S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1438},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/x7z03ez5'},
#           {'category': 'prklq2n9',
#            'comment': '19:51 mission time\r\n'
#                       '\r\n'
#                       'http://rankings.the-elite.net/goldeneye/single-segments/72',
#            'date': '2011-08-01',
#            'game': 'nj1ne1p4',
#            'id': '90y6ppm7',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/90y6ppm7'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'},
#                      {'rel': 'region',
#                       'uri': 'https://www.speedrun.com/api/v1/regions/pr184lqn'}],
#            'players': [{'name': 'Axel Z',
#                         'rel': 'guest',
#                         'uri': 'https://www.speedrun.com/api/v1/guests/Axel+Z'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': 'pr184lqn'},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT24M',
#                      'primary_t': 1440,
#                      'realtime': 'PT24M',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1440},
#            'values': {},
#            'videos': {'links': [{'uri': 'http://www.youtu.be/OYsSOy5aWVI'}]},
#            'weblink': 'https://www.speedrun.com/ge/run/90y6ppm7'},
#           {'category': 'prklq2n9',
#            'comment': 'This was the sgdq last minute run. The only run that '
#                       'was ever timed, and the only run I ever care to do!',
#            'date': None,
#            'game': 'nj1ne1p4',
#            'id': 'k8y891m1',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/k8y891m1'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'},
#                      {'rel': 'examiner',
#                       'uri': 'https://www.speedrun.com/api/v1/users/zxz7z0jq'}],
#            'players': [{'name': 'BassBoost',
#                         'rel': 'guest',
#                         'uri': 'https://www.speedrun.com/api/v1/guests/BassBoost'}],
#            'splits': None,
#            'status': {'examiner': 'zxz7z0jq',
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT24M4S',
#                      'primary_t': 1444,
#                      'realtime': 'PT24M4S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1444},
#            'values': {},
#            'videos': {'links': [{'uri': 'http://www.youtube.com/watch?v=6ZcDvcuColg'}]},
#            'weblink': 'https://www.speedrun.com/ge/run/k8y891m1'},
#           {'category': 'prklq2n9',
#            'comment': '\r',
#            'date': '2004-07-02',
#            'game': 'nj1ne1p4',
#            'id': 'n8yvj6yo',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/n8yvj6yo'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'name': 'Peter_Osterland',
#                         'rel': 'guest',
#                         'uri': 'https://www.speedrun.com/api/v1/guests/Peter_Osterland'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT24M5S',
#                      'primary_t': 1445,
#                      'realtime': 'PT24M5S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1445},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/n8yvj6yo'},
#           {'category': 'prklq2n9',
#            'comment': '\r',
#            'date': None,
#            'game': 'nj1ne1p4',
#            'id': 'j0zn43mn',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/j0zn43mn'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'id': 'v48gerjp',
#                         'rel': 'user',
#                         'uri': 'https://www.speedrun.com/api/v1/users/v48gerjp'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT24M31S',
#                      'primary_t': 1471,
#                      'realtime': 'PT24M31S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1471},
#            'values': {},
#            'videos': {'links': [{'uri': 'http://www.youtube.com/watch?v=-YD31rdJsVs'}]},
#            'weblink': 'https://www.speedrun.com/ge/run/j0zn43mn'},
#           {'category': 'prklq2n9',
#            'comment': None,
#            'date': '2014-01-04',
#            'game': 'nj1ne1p4',
#            'id': '26yj4gyd',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/26yj4gyd'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'id': '7j4nevx1',
#                         'rel': 'user',
#                         'uri': 'https://www.speedrun.com/api/v1/users/7j4nevx1'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT23M41S',
#                      'primary_t': 1421,
#                      'realtime': 'PT23M41S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1421},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/26yj4gyd'},
#           {'category': 'prklq2n9',
#            'comment': '\r',
#            'date': None,
#            'game': 'nj1ne1p4',
#            'id': 'n7yl4rmp',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/n7yl4rmp'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'name': 'Paul_Shephard',
#                         'rel': 'guest',
#                         'uri': 'https://www.speedrun.com/api/v1/guests/Paul_Shephard'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT24M56S',
#                      'primary_t': 1496,
#                      'realtime': 'PT24M56S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1496},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/n7yl4rmp'},
#           {'category': 'prklq2n9',
#            'comment': '\r',
#            'date': None,
#            'game': 'nj1ne1p4',
#            'id': 'rpzg7dz2',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/rpzg7dz2'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'name': 'Mgay',
#                         'rel': 'guest',
#                         'uri': 'https://www.speedrun.com/api/v1/guests/Mgay'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT24M57S',
#                      'primary_t': 1497,
#                      'realtime': 'PT24M57S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1497},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/rpzg7dz2'},
#           {'category': 'prklq2n9',
#            'comment': '\r',
#            'date': None,
#            'game': 'nj1ne1p4',
#            'id': 'x9me83m7',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/x9me83m7'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'id': 'ge8e6dj0',
#                         'rel': 'user',
#                         'uri': 'https://www.speedrun.com/api/v1/users/ge8e6dj0'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT25M37S',
#                      'primary_t': 1537,
#                      'realtime': 'PT25M37S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1537},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/x9me83m7'},
#           {'category': 'prklq2n9',
#            'comment': 'Sub-25 would be nice.',
#            'date': '2013-10-10',
#            'game': 'nj1ne1p4',
#            'id': 'j9yo2dzx',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/j9yo2dzx'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'name': 'Phazonn',
#                         'rel': 'guest',
#                         'uri': 'https://www.speedrun.com/api/v1/guests/Phazonn'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT25M37S',
#                      'primary_t': 1537,
#                      'realtime': 'PT25M37S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1537},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/j9yo2dzx'},
#           {'category': 'prklq2n9',
#            'comment': 'Goofy Control, had to get Body Armor. Tied Flicker!',
#            'date': '2013-12-10',
#            'game': 'nj1ne1p4',
#            'id': '1wzp0gmq',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/1wzp0gmq'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'id': 'kjprmv28',
#                         'rel': 'user',
#                         'uri': 'https://www.speedrun.com/api/v1/users/kjprmv28'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT25M49S',
#                      'primary_t': 1549,
#                      'realtime': 'PT25M49S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1549},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/1wzp0gmq'},
#           {'category': 'prklq2n9',
#            'comment': '\r',
#            'date': '2007-05-20',
#            'game': 'nj1ne1p4',
#            'id': 'opyd3jzn',
#            'level': None,
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/runs/opyd3jzn'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nj1ne1p4'},
#                      {'rel': 'category',
#                       'uri': 'https://www.speedrun.com/api/v1/categories/prklq2n9'},
#                      {'rel': 'platform',
#                       'uri': 'https://www.speedrun.com/api/v1/platforms/w89rwelk'}],
#            'players': [{'name': 'ajbownes',
#                         'rel': 'guest',
#                         'uri': 'https://www.speedrun.com/api/v1/guests/ajbownes'}],
#            'splits': None,
#            'status': {'examiner': None,
#                       'status': 'verified',
#                       'verify-date': None},
#            'submitted': None,
#            'system': {'emulated': False,
#                       'platform': 'w89rwelk',
#                       'region': None},
#            'times': {'ingame': None,
#                      'ingame_t': 0,
#                      'primary': 'PT26M16S',
#                      'primary_t': 1576,
#                      'realtime': 'PT26M16S',
#                      'realtime_noloads': None,
#                      'realtime_noloads_t': 0,
#                      'realtime_t': 1576},
#            'values': {},
#            'videos': None,
#            'weblink': 'https://www.speedrun.com/ge/run/opyd3jzn'}],
#  'pagination': {'links': [{'rel': 'next',
#                            'uri': 'https://www.speedrun.com/api/v1/runs?offset=20'}],
#                 'max': 20,
#                 'offset': 0,
#                 'size': 20}}

# %%
pprint(runs_data['data'][0])

# %%
url = "https://www.speedrun.com/api/v1/games?name=LEGO%20Star%20Wars"

# %%
response = requests.get(url)
print(response.url)
# Out:
# https://www.speedrun.com/api/v1/games?name=LEGO%20Star%20Wars

# %%
lego_data = response.json()
pprint(lego_data)
# Out:
# {'data': [{'abbreviation': 'lsw',
#            'assets': {'background': {'height': 1080,
#                                      'uri': 'https://www.speedrun.com/themes/lsw/background.png',
#                                      'width': 1920},
#                       'cover-large': {'height': 360,
#                                       'uri': 'https://www.speedrun.com/themes/lsw/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 180,
#                                        'uri': 'https://www.speedrun.com/themes/lsw/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 90,
#                                       'uri': 'https://www.speedrun.com/themes/lsw/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 45,
#                                      'uri': 'https://www.speedrun.com/themes/lsw/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/lsw/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 32,
#                                'uri': 'https://www.speedrun.com/themes/lsw/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lsw/1st.png',
#                                      'width': 16},
#                       'trophy-2nd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lsw/2nd.png',
#                                      'width': 16},
#                       'trophy-3rd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lsw/3rd.png',
#                                      'width': 16},
#                       'trophy-4th': None},
#            'created': None,
#            'developers': ['ynzmy5z0'],
#            'engines': [],
#            'gametypes': [],
#            'genres': ['9rnvvrnq'],
#            'id': 'yd4oog1e',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=yd4oog1e'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/87m99j46'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/5nddx0nr'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/yd4oog1e/category/ndx8wvkq'}],
#            'moderators': {'qj252mnj': 'super-moderator',
#                           'y8d0rd9x': 'moderator'},
#            'names': {'international': 'LEGO Star Wars: The Video Game',
#                      'japanese': None,
#                      'twitch': 'LEGO Star Wars: The Video Game'},
#            'platforms': ['4p9z06rn', 'n5e17e27', 'jm95zz9o', '8gej2n93'],
#            'publishers': ['l6mo38r9', '93nkxrw4'],
#            'regions': [],
#            'release-date': '2005-04-02',
#            'released': 2005,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': False,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/lsw'},
#           {'abbreviation': 'lsw3',
#            'assets': {'background': {'height': 1080,
#                                      'uri': 'https://www.speedrun.com/themes/lsw3/background.png',
#                                      'width': 1920},
#                       'cover-large': {'height': 328,
#                                       'uri': 'https://www.speedrun.com/themes/lsw3/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 164,
#                                        'uri': 'https://www.speedrun.com/themes/lsw3/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 82,
#                                       'uri': 'https://www.speedrun.com/themes/lsw3/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 41,
#                                      'uri': 'https://www.speedrun.com/themes/lsw3/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 16,
#                                'uri': 'https://www.speedrun.com/themes/lsw3/favicon.png',
#                                'width': 16},
#                       'logo': {'height': 24,
#                                'uri': 'https://www.speedrun.com/themes/lsw3/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 63,
#                                      'uri': 'https://www.speedrun.com/themes/lsw3/1st.png',
#                                      'width': 64},
#                       'trophy-2nd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/lsw3/2nd.png',
#                                      'width': 64},
#                       'trophy-3rd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/lsw3/3rd.png',
#                                      'width': 64},
#                       'trophy-4th': {'height': 63,
#                                      'uri': 'https://www.speedrun.com/themes/lsw3/4th.png',
#                                      'width': 64}},
#            'created': '2015-07-23T21:19:34Z',
#            'developers': [],
#            'engines': [],
#            'gametypes': [],
#            'genres': [],
#            'id': 'lde0vn63',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/lde0vn63'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=lde0vn63'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/lde0vn63/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/lde0vn63/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/lde0vn63/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/lde0vn63/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/87m99j46'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/5nddx0nr'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/lde0vn63/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/lde0vn63/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/lde0vn63/category/7kjvz0zk'}],
#            'moderators': {'48g562yj': 'moderator',
#                           'o86zogpx': 'super-moderator'},
#            'names': {'international': 'LEGO Star Wars III: The Clone Wars',
#                      'japanese': None,
#                      'twitch': 'LEGO Star Wars III: The Clone Wars'},
#            'platforms': ['mx6pwe3g',
#                          'n568oevp',
#                          'nzelkr6q',
#                          '8gej2n93',
#                          'v06dk3e4'],
#            'publishers': [],
#            'regions': ['pr184lqn', 'e6lxy1dz'],
#            'release-date': '2011-03-22',
#            'released': 2011,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': False,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/lsw3'},
#           {'abbreviation': 'lswtyc',
#            'assets': {'background': {'height': 523,
#                                      'uri': 'https://www.speedrun.com/themes/lswtyc/background.png',
#                                      'width': 1368},
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/lswtyc/cover-256.png',
#                                       'width': 360},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/lswtyc/cover-128.png',
#                                        'width': 180},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/lswtyc/cover-64.png',
#                                       'width': 90},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/lswtyc/cover-32.png',
#                                      'width': 45},
#                       'foreground': None,
#                       'icon': {'height': 16,
#                                'uri': 'https://www.speedrun.com/themes/lswtyc/favicon.png',
#                                'width': 16},
#                       'logo': {'height': 24,
#                                'uri': 'https://www.speedrun.com/themes/lswtyc/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtyc/1st.png',
#                                      'width': 16},
#                       'trophy-2nd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtyc/2nd.png',
#                                      'width': 16},
#                       'trophy-3rd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtyc/3rd.png',
#                                      'width': 16},
#                       'trophy-4th': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtyc/4th.png',
#                                      'width': 16}},
#            'created': '2020-02-07T22:10:42Z',
#            'developers': ['rzj07n6l'],
#            'engines': [],
#            'gametypes': [],
#            'genres': ['oq2712l7', 'o75mg539'],
#            'id': 'o6glo5od',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o6glo5od'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=o6glo5od'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o6glo5od/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o6glo5od/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o6glo5od/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o6glo5od/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/87m99j46'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o6glo5od/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o6glo5od/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/o6glo5od/category/jdrvn8x2'}],
#            'moderators': {'48g562yj': 'super-moderator',
#                           '814wkd58': 'moderator'},
#            'names': {'international': 'LEGO Star Wars: The Yoda Chronicles',
#                      'japanese': None,
#                      'twitch': 'LEGO Star Wars: The Yoda Chronicles'},
#            'platforms': ['8gej2n93', 'lq60nl94', 'gde3xgek'],
#            'publishers': ['l6m5e1n9'],
#            'regions': [],
#            'release-date': '2013-05-03',
#            'released': 2013,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime', 'ingame'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/lswtyc'},
#           {'abbreviation': 'lswgba',
#            'assets': {'background': {'height': 900,
#                                      'uri': 'https://www.speedrun.com/themes/lego/background.png',
#                                      'width': 1440},
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/lswgba/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/lswgba/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/lswgba/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/lswgba/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 16,
#                                'uri': 'https://www.speedrun.com/themes/lego/favicon.png',
#                                'width': 16},
#                       'logo': {'height': 24,
#                                'uri': 'https://www.speedrun.com/themes/lego/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 63,
#                                      'uri': 'https://www.speedrun.com/themes/lego/1st.png',
#                                      'width': 64},
#                       'trophy-2nd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/lego/2nd.png',
#                                      'width': 64},
#                       'trophy-3rd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/lego/3rd.png',
#                                      'width': 64},
#                       'trophy-4th': {'height': 63,
#                                      'uri': 'https://www.speedrun.com/themes/lego/4th.png',
#                                      'width': 64}},
#            'created': '2016-06-04T23:49:01Z',
#            'developers': [],
#            'engines': [],
#            'gametypes': [],
#            'genres': [],
#            'id': 'j1nrkedp',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1nrkedp'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=j1nrkedp'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1nrkedp/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1nrkedp/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1nrkedp/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1nrkedp/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/87m99j46'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/5nddx0nr'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1nrkedp/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1nrkedp/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/j1nrkedp/category/7dggrjgd'}],
#            'moderators': {'qj20vlxk': 'super-moderator'},
#            'names': {'international': 'LEGO Star Wars: The Video Game (GBA)',
#                      'japanese': None,
#                      'twitch': 'LEGO Star Wars: The Video Game'},
#            'platforms': ['3167d6q2'],
#            'publishers': [],
#            'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#            'release-date': '2005-03-29',
#            'released': 2005,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/lswgba'},
#           {'abbreviation': 'lswtcsds',
#            'assets': {'background': None,
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/lswtcsds/cover-256.png',
#                                       'width': 288},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/lswtcsds/cover-128.png',
#                                        'width': 144},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/lswtcsds/cover-64.png',
#                                       'width': 72},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcsds/cover-32.png',
#                                      'width': 36},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/Default/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 32,
#                                'uri': 'https://www.speedrun.com/themes/lswtcsds/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcsds/1st.png',
#                                      'width': 64},
#                       'trophy-2nd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcsds/2nd.png',
#                                      'width': 64},
#                       'trophy-3rd': {'height': 63,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcsds/3rd.png',
#                                      'width': 64},
#                       'trophy-4th': None},
#            'created': '2016-06-11T16:28:14Z',
#            'developers': [],
#            'engines': [],
#            'gametypes': [],
#            'genres': [],
#            'id': 'nd2xjq60',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nd2xjq60'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=nd2xjq60'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nd2xjq60/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nd2xjq60/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nd2xjq60/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nd2xjq60/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/87m99j46'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/5nddx0nr'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nd2xjq60/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/nd2xjq60/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/nd2xjq60/category/mke5w36k'}],
#            'moderators': {'18vqg45j': 'moderator',
#                           'zxz9onr8': 'super-moderator'},
#            'names': {'international': 'LEGO Star Wars: The Complete Saga (DS)',
#                      'japanese': None,
#                      'twitch': 'LEGO Star Wars: The Complete Saga'},
#            'platforms': ['7g6m8erk', 'gz9qx60q', 'kz9wqn9p'],
#            'publishers': [],
#            'regions': [],
#            'release-date': '2007-11-06',
#            'released': 2007,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/lswtcsds'},
#           {'abbreviation': 'lswtnyc',
#            'assets': {'background': None,
#                       'cover-large': {'height': 360,
#                                       'uri': 'https://www.speedrun.com/themes/lswtnyc/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 180,
#                                        'uri': 'https://www.speedrun.com/themes/lswtnyc/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 90,
#                                       'uri': 'https://www.speedrun.com/themes/lswtnyc/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 45,
#                                      'uri': 'https://www.speedrun.com/themes/lswtnyc/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 16,
#                                'uri': 'https://www.speedrun.com/themes/lswtnyc/favicon.png',
#                                'width': 16},
#                       'logo': {'height': 78,
#                                'uri': 'https://www.speedrun.com/themes/Default/logo.png',
#                                'width': 640},
#                       'trophy-1st': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtnyc/1st.png',
#                                      'width': 16},
#                       'trophy-2nd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtnyc/2nd.png',
#                                      'width': 16},
#                       'trophy-3rd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtnyc/3rd.png',
#                                      'width': 16},
#                       'trophy-4th': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtnyc/4th.png',
#                                      'width': 16}},
#            'created': '2020-03-22T23:25:01Z',
#            'developers': [],
#            'engines': [],
#            'gametypes': [],
#            'genres': [],
#            'id': '76rxeol6',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxeol6'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=76rxeol6'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxeol6/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxeol6/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxeol6/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxeol6/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/87m99j46'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxeol6/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxeol6/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/76rxeol6/category/zd3wz0ek'}],
#            'moderators': {'48g562yj': 'super-moderator',
#                           '814wkd58': 'moderator'},
#            'names': {'international': 'LEGO Star Wars: The New Yoda Chronicles',
#                      'japanese': None,
#                      'twitch': 'LEGO Star Wars: The New Yoda Chronicles'},
#            'platforms': ['lq60nl94', 'gde3xgek', 'o7e25xew'],
#            'publishers': [],
#            'regions': [],
#            'release-date': '2014-09-04',
#            'released': 2014,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/lswtnyc'},
#           {'abbreviation': 'lsw2ds',
#            'assets': {'background': None,
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/lsw2ds/cover-256.png',
#                                       'width': 288},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/lsw2ds/cover-128.png',
#                                        'width': 144},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/lsw2ds/cover-64.png',
#                                       'width': 72},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2ds/cover-32.png',
#                                      'width': 36},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/Default/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 78,
#                                'uri': 'https://www.speedrun.com/themes/Default/logo.png',
#                                'width': 640},
#                       'trophy-1st': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2ds/1st.png',
#                                      'width': 64},
#                       'trophy-2nd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2ds/2nd.png',
#                                      'width': 64},
#                       'trophy-3rd': {'height': 63,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2ds/3rd.png',
#                                      'width': 64},
#                       'trophy-4th': None},
#            'created': '2016-10-23T03:07:18Z',
#            'developers': [],
#            'engines': [],
#            'gametypes': [],
#            'genres': [],
#            'id': 'yd4j45de',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4j45de'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=yd4j45de'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4j45de/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4j45de/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4j45de/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4j45de/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/87m99j46'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/5nddx0nr'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4j45de/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4j45de/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/yd4j45de/category/9d8v84wk'}],
#            'moderators': {'68w14evx': 'super-moderator'},
#            'names': {'international': 'LEGO Star Wars II: The Original Trilogy '
#                                       '(DS)',
#                      'japanese': None,
#                      'twitch': 'LEGO Star Wars II: The Original Trilogy'},
#            'platforms': ['7g6m8erk', 'gz9qx60q', 'kz9wqn9p'],
#            'publishers': [],
#            'regions': ['pr184lqn', 'e6lxy1dz'],
#            'release-date': '2006-09-11',
#            'released': 2006,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': False,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/lsw2ds'},
#           {'abbreviation': 'lsw2gba',
#            'assets': {'background': None,
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/lsw2gba/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/lsw2gba/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/lsw2gba/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2gba/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/Default/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 78,
#                                'uri': 'https://www.speedrun.com/themes/Default/logo.png',
#                                'width': 640},
#                       'trophy-1st': {'height': 63,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2gba/1st.png',
#                                      'width': 64},
#                       'trophy-2nd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2gba/2nd.png',
#                                      'width': 64},
#                       'trophy-3rd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2gba/3rd.png',
#                                      'width': 64},
#                       'trophy-4th': {'height': 63,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2gba/4th.png',
#                                      'width': 64}},
#            'created': '2017-06-26T00:20:26Z',
#            'developers': ['ynzmy5z0', '1zkkx9zj'],
#            'engines': [],
#            'gametypes': [],
#            'genres': ['9rnvvrnq'],
#            'id': 'pd08wv1e',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd08wv1e'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=pd08wv1e'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd08wv1e/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd08wv1e/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd08wv1e/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd08wv1e/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/87m99j46'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/5nddx0nr'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd08wv1e/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd08wv1e/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/pd08wv1e/category/vdoqv7yk'}],
#            'moderators': {'7j4r9558': 'super-moderator',
#                           'zx744vvx': 'super-moderator'},
#            'names': {'international': 'LEGO Star Wars II: The Original Trilogy '
#                                       '(GBA)',
#                      'japanese': None,
#                      'twitch': 'LEGO Star Wars II: The Original Trilogy'},
#            'platforms': ['3167d6q2', '7m6yvw6p'],
#            'publishers': ['gxrw36l2'],
#            'regions': [],
#            'release-date': '2006-09-11',
#            'released': 2006,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/lsw2gba'},
#           {'abbreviation': 'lswtcs',
#            'assets': {'background': {'height': 1080,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcs/background.png',
#                                      'width': 1920},
#                       'cover-large': {'height': 360,
#                                       'uri': 'https://www.speedrun.com/themes/lswtcs/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 180,
#                                        'uri': 'https://www.speedrun.com/themes/lswtcs/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 90,
#                                       'uri': 'https://www.speedrun.com/themes/lswtcs/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 45,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcs/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 16,
#                                'uri': 'https://www.speedrun.com/themes/lswtcs/favicon.png',
#                                'width': 16},
#                       'logo': {'height': 24,
#                                'uri': 'https://www.speedrun.com/themes/lswtcs/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcs/1st.png',
#                                      'width': 16},
#                       'trophy-2nd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcs/2nd.png',
#                                      'width': 16},
#                       'trophy-3rd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcs/3rd.png',
#                                      'width': 16},
#                       'trophy-4th': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcs/4th.png',
#                                      'width': 16}},
#            'created': None,
#            'developers': ['ynzmy5z0'],
#            'engines': [],
#            'gametypes': [],
#            'genres': ['o75mg539', 'qdnqkn8k'],
#            'id': '46w33l1r',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/46w33l1r'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=46w33l1r'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/46w33l1r/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/46w33l1r/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/46w33l1r/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/46w33l1r/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/87m99j46'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/5nddx0nr'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/46w33l1r/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/46w33l1r/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/46w33l1r/category/9d8p7ylk'}],
#            'moderators': {'48g562yj': 'super-moderator',
#                           'e8e0oqpj': 'moderator',
#                           'y8d0rd9x': 'moderator',
#                           'zx744vvx': 'moderator',
#                           'zxz19ejq': 'super-moderator'},
#            'names': {'international': 'LEGO Star Wars: The Complete Saga '
#                                       '(PC/Console)',
#                      'japanese': None,
#                      'twitch': 'LEGO Star Wars: The Complete Saga'},
#            'platforms': ['8gejn93d',
#                          'mx6pwe3g',
#                          'n568oevp',
#                          'nzelkr6q',
#                          'o7e2mx6w',
#                          '8gej2n93',
#                          'v06dk3e4',
#                          'lq60nl94',
#                          'gde3xgek'],
#            'publishers': ['gxrw36l2'],
#            'regions': [],
#            'release-date': '2007-11-06',
#            'released': 2007,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': False,
#                        'require-verification': True,
#                        'require-video': False,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/lswtcs'},
#           {'abbreviation': 'lsw2',
#            'assets': {'background': {'height': 1080,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2/background.png',
#                                      'width': 1920},
#                       'cover-large': {'height': 360,
#                                       'uri': 'https://www.speedrun.com/themes/lsw2/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 180,
#                                        'uri': 'https://www.speedrun.com/themes/lsw2/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 90,
#                                       'uri': 'https://www.speedrun.com/themes/lsw2/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 45,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 16,
#                                'uri': 'https://www.speedrun.com/themes/lsw2/favicon.png',
#                                'width': 16},
#                       'logo': {'height': 32,
#                                'uri': 'https://www.speedrun.com/themes/lsw2/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 63,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2/1st.png',
#                                      'width': 64},
#                       'trophy-2nd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2/2nd.png',
#                                      'width': 64},
#                       'trophy-3rd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2/3rd.png',
#                                      'width': 64},
#                       'trophy-4th': {'height': 63,
#                                      'uri': 'https://www.speedrun.com/themes/lsw2/4th.png',
#                                      'width': 64}},
#            'created': None,
#            'developers': ['ynzmy5z0', '1zkkx9zj'],
#            'engines': ['p85eg716'],
#            'gametypes': [],
#            'genres': ['9rnvvrnq'],
#            'id': '3dx2251y',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/3dx2251y'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=3dx2251y'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/3dx2251y/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/3dx2251y/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/3dx2251y/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/3dx2251y/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/87m99j46'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/5nddx0nr'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/3dx2251y/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/3dx2251y/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/3dx2251y/category/wkpyl8kr'}],
#            'moderators': {'7j4r9558': 'super-moderator',
#                           'y8d0rd9x': 'super-moderator',
#                           'zx744vvx': 'super-moderator'},
#            'names': {'international': 'LEGO Star Wars II: The Original Trilogy '
#                                       '(Console)',
#                      'japanese': None,
#                      'twitch': 'LEGO Star Wars II: The Original Trilogy'},
#            'platforms': ['4p9z06rn',
#                          'n5e17e27',
#                          '5negk9y7',
#                          'n568oevp',
#                          'jm95zz9o',
#                          'o7e2mx6w',
#                          '8gej2n93'],
#            'publishers': ['gxrw36l2', '3nkqomnw'],
#            'regions': ['pr184lqn', 'e6lxy1dz'],
#            'release-date': '2006-09-11',
#            'released': 2006,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': False,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/lsw2'},
#           {'abbreviation': 'lswtcsce',
#            'assets': {'background': {'height': 1080,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcsce/background.png',
#                                      'width': 1920},
#                       'cover-large': {'height': 328,
#                                       'uri': 'https://www.speedrun.com/themes/lswtcsce/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 164,
#                                        'uri': 'https://www.speedrun.com/themes/lswtcsce/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 82,
#                                       'uri': 'https://www.speedrun.com/themes/lswtcsce/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 41,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcsce/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 16,
#                                'uri': 'https://www.speedrun.com/themes/lswtcsce/favicon.png',
#                                'width': 16},
#                       'logo': {'height': 24,
#                                'uri': 'https://www.speedrun.com/themes/lswtcsce/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcsce/1st.png',
#                                      'width': 16},
#                       'trophy-2nd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcsce/2nd.png',
#                                      'width': 16},
#                       'trophy-3rd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcsce/3rd.png',
#                                      'width': 16},
#                       'trophy-4th': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/lswtcsce/4th.png',
#                                      'width': 16}},
#            'created': '2019-06-04T01:19:26Z',
#            'developers': ['ynzmy5z0'],
#            'engines': [],
#            'gametypes': ['53no817x'],
#            'genres': ['o75mg539'],
#            'id': 'j1ll22j1',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1ll22j1'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=j1ll22j1'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1ll22j1/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1ll22j1/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1ll22j1/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1ll22j1/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/87m99j46'},
#                      {'rel': 'base-game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/46w33l1r'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/46w33l1r'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1ll22j1/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/j1ll22j1/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/j1ll22j1/category/wkpmr88k'}],
#            'moderators': {'48g562yj': 'super-moderator',
#                           'e8e0oqpj': 'super-moderator',
#                           'y8d0rd9x': 'moderator',
#                           'zx744vvx': 'moderator',
#                           'zxz19ejq': 'super-moderator'},
#            'names': {'international': 'LEGO Star Wars: The Complete Saga '
#                                       'Category Extensions',
#                      'japanese': None,
#                      'twitch': 'LEGO Star Wars: The Complete Saga Category '
#                                'Extensions'},
#            'platforms': ['8gejn93d',
#                          'mx6pwe3g',
#                          'n568oevp',
#                          'o7e2mx6w',
#                          '8gej2n93',
#                          'v06dk3e4',
#                          'lq60nl94',
#                          'gde3xgek'],
#            'publishers': ['gxrw36l2'],
#            'regions': [],
#            'release-date': '2007-11-06',
#            'released': 2007,
#            'romhack': True,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': False,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/lswtcsce'}],
#  'pagination': {'links': [], 'max': 20, 'offset': 0, 'size': 11}}

# %%
lego_data = lego_data['data']

# %%
lego_data = lego_data[0]

# %%
pprint(lego_data)
# Out:
# {'abbreviation': 'lsw',
#  'assets': {'background': {'height': 1080,
#                            'uri': 'https://www.speedrun.com/themes/lsw/background.png',
#                            'width': 1920},
#             'cover-large': {'height': 360,
#                             'uri': 'https://www.speedrun.com/themes/lsw/cover-256.png',
#                             'width': 256},
#             'cover-medium': {'height': 180,
#                              'uri': 'https://www.speedrun.com/themes/lsw/cover-128.png',
#                              'width': 128},
#             'cover-small': {'height': 90,
#                             'uri': 'https://www.speedrun.com/themes/lsw/cover-64.png',
#                             'width': 64},
#             'cover-tiny': {'height': 45,
#                            'uri': 'https://www.speedrun.com/themes/lsw/cover-32.png',
#                            'width': 32},
#             'foreground': None,
#             'icon': {'height': 64,
#                      'uri': 'https://www.speedrun.com/themes/lsw/favicon.png',
#                      'width': 64},
#             'logo': {'height': 32,
#                      'uri': 'https://www.speedrun.com/themes/lsw/logo.png',
#                      'width': 180},
#             'trophy-1st': {'height': 16,
#                            'uri': 'https://www.speedrun.com/themes/lsw/1st.png',
#                            'width': 16},
#             'trophy-2nd': {'height': 16,
#                            'uri': 'https://www.speedrun.com/themes/lsw/2nd.png',
#                            'width': 16},
#             'trophy-3rd': {'height': 16,
#                            'uri': 'https://www.speedrun.com/themes/lsw/3rd.png',
#                            'width': 16},
#             'trophy-4th': None},
#  'created': None,
#  'developers': ['ynzmy5z0'],
#  'engines': [],
#  'gametypes': [],
#  'genres': ['9rnvvrnq'],
#  'id': 'yd4oog1e',
#  'links': [{'rel': 'self',
#             'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e'},
#            {'rel': 'runs',
#             'uri': 'https://www.speedrun.com/api/v1/runs?game=yd4oog1e'},
#            {'rel': 'levels',
#             'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e/levels'},
#            {'rel': 'categories',
#             'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e/categories'},
#            {'rel': 'variables',
#             'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e/variables'},
#            {'rel': 'records',
#             'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e/records'},
#            {'rel': 'series',
#             'uri': 'https://www.speedrun.com/api/v1/series/87m99j46'},
#            {'rel': 'series',
#             'uri': 'https://www.speedrun.com/api/v1/series/5nddx0nr'},
#            {'rel': 'derived-games',
#             'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e/derived-games'},
#            {'rel': 'romhacks',
#             'uri': 'https://www.speedrun.com/api/v1/games/yd4oog1e/derived-games'},
#            {'rel': 'leaderboard',
#             'uri': 'https://www.speedrun.com/api/v1/leaderboards/yd4oog1e/category/ndx8wvkq'}],
#  'moderators': {'qj252mnj': 'super-moderator', 'y8d0rd9x': 'moderator'},
#  'names': {'international': 'LEGO Star Wars: The Video Game',
#            'japanese': None,
#            'twitch': 'LEGO Star Wars: The Video Game'},
#  'platforms': ['4p9z06rn', 'n5e17e27', 'jm95zz9o', '8gej2n93'],
#  'publishers': ['l6mo38r9', '93nkxrw4'],
#  'regions': [],
#  'release-date': '2005-04-02',
#  'released': 2005,
#  'romhack': False,
#  'ruleset': {'default-time': 'realtime',
#              'emulators-allowed': True,
#              'require-verification': True,
#              'require-video': False,
#              'run-times': ['realtime'],
#              'show-milliseconds': False},
#  'weblink': 'https://www.speedrun.com/lsw'}

# %%
url = "https://www.speedrun.com/api/v1/games?name=Super%20Mario"

# %%
response = requests.get(url)
print(response.url)
# Out:
# https://www.speedrun.com/api/v1/games?name=Super%20Mario

# %%
mario_data = response.json()
pprint(mario_data)
# Out:
# {'data': [{'abbreviation': 'sm74',
#            'assets': {'background': {'height': 480,
#                                      'uri': 'https://www.speedrun.com/themes/sm74/background.png',
#                                      'width': 640},
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/sm74/cover-256.png',
#                                       'width': 360},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/sm74/cover-128.png',
#                                        'width': 180},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/sm74/cover-64.png',
#                                       'width': 90},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/sm74/cover-32.png',
#                                      'width': 45},
#                       'foreground': None,
#                       'icon': {'height': 16,
#                                'uri': 'https://www.speedrun.com/themes/sm74/favicon.png',
#                                'width': 16},
#                       'logo': {'height': 78,
#                                'uri': 'https://www.speedrun.com/themes/Default/logo.png',
#                                'width': 640},
#                       'trophy-1st': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/sm74/1st.png',
#                                      'width': 16},
#                       'trophy-2nd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/sm74/2nd.png',
#                                      'width': 16},
#                       'trophy-3rd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/sm74/3rd.png',
#                                      'width': 16},
#                       'trophy-4th': None},
#            'created': '2015-02-09T04:24:46Z',
#            'developers': [],
#            'engines': [],
#            'gametypes': ['v4m291qw'],
#            'genres': [],
#            'id': 'y65z836e',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65z836e'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=y65z836e'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65z836e/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65z836e/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65z836e/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65z836e/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/0499o64v'},
#                      {'rel': 'base-game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65z836e/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65z836e/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/y65z836e/category/vdo0pn1d'}],
#            'moderators': {'18v52d5j': 'moderator',
#                           'o864qpjz': 'super-moderator',
#                           'pj0n70m8': 'super-moderator',
#                           'qjopronx': 'super-moderator',
#                           'qxkm6d2j': 'moderator',
#                           'v8lyv4jm': 'super-moderator'},
#            'names': {'international': 'Super Mario 74',
#                      'japanese': None,
#                      'twitch': 'Super Mario 64'},
#            'platforms': ['w89rwelk', 'nzelreqp', 'v06dr394'],
#            'publishers': [],
#            'regions': [],
#            'release-date': '2010-11-18',
#            'released': 2010,
#            'romhack': True,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/sm74'},
#           {'abbreviation': 'sm32',
#            'assets': {'background': None,
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/sm32/cover-256.png',
#                                       'width': 360},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/sm32/cover-128.png',
#                                        'width': 180},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/sm32/cover-64.png',
#                                       'width': 90},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/sm32/cover-32.png',
#                                      'width': 45},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/Default/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 78,
#                                'uri': 'https://www.speedrun.com/themes/Default/logo.png',
#                                'width': 640},
#                       'trophy-1st': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/sm32/1st.png',
#                                      'width': 16},
#                       'trophy-2nd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/sm32/2nd.png',
#                                      'width': 16},
#                       'trophy-3rd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/sm32/3rd.png',
#                                      'width': 16},
#                       'trophy-4th': None},
#            'created': '2018-10-09T17:21:24Z',
#            'developers': ['v69m4vzx'],
#            'engines': [],
#            'gametypes': [],
#            'genres': [],
#            'id': 'o1y95mr6',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95mr6'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=o1y95mr6'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95mr6/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95mr6/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95mr6/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95mr6/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/0499o64v'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95mr6/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95mr6/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/o1y95mr6/category/7kjqwzzd'}],
#            'moderators': {'18v52d5j': 'moderator',
#                           '7j420lwx': 'moderator',
#                           'pj0n70m8': 'super-moderator',
#                           'qjopronx': 'super-moderator',
#                           'qxkm6d2j': 'moderator',
#                           'v8lyv4jm': 'super-moderator'},
#            'names': {'international': 'Super Mario 32',
#                      'japanese': None,
#                      'twitch': 'Super Mario 32'},
#            'platforms': ['w89rwelk', 'nzelreqp', 'v06dr394'],
#            'publishers': [],
#            'regions': [],
#            'release-date': '2018-08-29',
#            'released': 2018,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/sm32'},
#           {'abbreviation': 'sm64',
#            'assets': {'background': {'height': 200,
#                                      'uri': 'https://www.speedrun.com/themes/sm64/background.png',
#                                      'width': 200},
#                       'cover-large': {'height': 360,
#                                       'uri': 'https://www.speedrun.com/themes/sm64/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 180,
#                                        'uri': 'https://www.speedrun.com/themes/sm64/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 90,
#                                       'uri': 'https://www.speedrun.com/themes/sm64/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 45,
#                                      'uri': 'https://www.speedrun.com/themes/sm64/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 16,
#                                'uri': 'https://www.speedrun.com/themes/sm64/favicon.png',
#                                'width': 16},
#                       'logo': {'height': 32,
#                                'uri': 'https://www.speedrun.com/themes/sm64/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/sm64/1st.png',
#                                      'width': 16},
#                       'trophy-2nd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/sm64/2nd.png',
#                                      'width': 16},
#                       'trophy-3rd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/sm64/3rd.png',
#                                      'width': 16},
#                       'trophy-4th': None},
#            'created': None,
#            'developers': ['xv6dvx62'],
#            'engines': [],
#            'gametypes': [],
#            'genres': ['jp23ox26'],
#            'id': 'o1y9wo6q',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=o1y9wo6q'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/rv7emz49'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/o1y9wo6q/category/zdnq4oqd'}],
#            'moderators': {'1xyky4n8': 'moderator',
#                           'e8e6edj0': 'super-moderator',
#                           'e8e9ze2j': 'super-moderator',
#                           'pj0n70m8': 'moderator',
#                           'qjo5lrl8': 'moderator',
#                           'qxk4wo6j': 'moderator',
#                           'v815edqj': 'moderator',
#                           'zx7gkrx7': 'super-moderator',
#                           'zxzvprjq': 'super-moderator'},
#            'names': {'international': 'Super Mario 64',
#                      'japanese': 'スーパーマリオ64',
#                      'twitch': 'Super Mario 64'},
#            'platforms': ['w89rwelk', 'nzelreqp', 'v06dr394'],
#            'publishers': ['m0rvylrx'],
#            'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#            'release-date': '1996-06-23',
#            'released': 1996,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/sm64'},
#           {'abbreviation': 'sm63',
#            'assets': {'background': None,
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/sm63/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/sm63/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/sm63/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/sm63/cover-32.png',
#                                      'width': 32},
#                       'foreground': {'height': 892,
#                                      'uri': 'https://www.speedrun.com/themes/sm63/foreground.png',
#                                      'width': 1228},
#                       'icon': {'height': 32,
#                                'uri': 'https://www.speedrun.com/themes/sm63/favicon.png',
#                                'width': 32},
#                       'logo': {'height': 78,
#                                'uri': 'https://www.speedrun.com/themes/Default/logo.png',
#                                'width': 640},
#                       'trophy-1st': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/sm63/1st.png',
#                                      'width': 16},
#                       'trophy-2nd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/sm63/2nd.png',
#                                      'width': 16},
#                       'trophy-3rd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/sm63/3rd.png',
#                                      'width': 16},
#                       'trophy-4th': None},
#            'created': '2015-02-10T00:43:13Z',
#            'developers': ['nw63rd6x'],
#            'engines': ['mg1j4w1r'],
#            'gametypes': ['d91jd1ex'],
#            'genres': ['qdnqkn8k'],
#            'id': 'kdkvl21m',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/kdkvl21m'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=kdkvl21m'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/kdkvl21m/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/kdkvl21m/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/kdkvl21m/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/kdkvl21m/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/xn05xx72'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/v7oqk940'},
#                      {'rel': 'base-game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/kdkvl21m/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/kdkvl21m/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/kdkvl21m/category/7kj99423'}],
#            'moderators': {'48grqp2x': 'moderator',
#                           '7j4gpevj': 'super-moderator',
#                           'kjp4o74j': 'moderator',
#                           'qjn1mw8m': 'super-moderator',
#                           'qjo1wmex': 'moderator',
#                           'zx7qr087': 'super-moderator'},
#            'names': {'international': 'Super Mario 63',
#                      'japanese': None,
#                      'twitch': 'Flash'},
#            'platforms': ['8gej2n93', 'o7e25xew'],
#            'publishers': ['yzr138n8'],
#            'regions': [],
#            'release-date': '2009-06-10',
#            'released': 2009,
#            'romhack': True,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': False,
#                        'require-verification': True,
#                        'require-video': False,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/sm63'},
#           {'abbreviation': 'smr',
#            'assets': {'background': {'height': 1080,
#                                      'uri': 'https://www.speedrun.com/themes/smr/background.png',
#                                      'width': 1920},
#                       'cover-large': {'height': 360,
#                                       'uri': 'https://www.speedrun.com/themes/smr/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 180,
#                                        'uri': 'https://www.speedrun.com/themes/smr/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 90,
#                                       'uri': 'https://www.speedrun.com/themes/smr/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 45,
#                                      'uri': 'https://www.speedrun.com/themes/smr/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/Default/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 32,
#                                'uri': 'https://www.speedrun.com/themes/smr/logo.png',
#                                'width': 176},
#                       'trophy-1st': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/smr/1st.png',
#                                      'width': 14},
#                       'trophy-2nd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/smr/2nd.png',
#                                      'width': 14},
#                       'trophy-3rd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/smr/3rd.png',
#                                      'width': 14},
#                       'trophy-4th': None},
#            'created': '2016-12-16T07:29:28Z',
#            'developers': ['xv6dvx62'],
#            'engines': [],
#            'gametypes': [],
#            'genres': ['qdnqkn8k'],
#            'id': 'y658876e',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y658876e'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=y658876e'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y658876e/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y658876e/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y658876e/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y658876e/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/rv7emz49'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y658876e/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y658876e/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/y658876e/category/02qj0xzd'}],
#            'moderators': {'qjn291dj': 'super-moderator',
#                           'y8d3zzox': 'super-moderator'},
#            'names': {'international': 'Super Mario Run',
#                      'japanese': None,
#                      'twitch': 'Super Mario Run'},
#            'platforms': ['lq60nl94', 'gde3xgek'],
#            'publishers': ['m0rvylrx'],
#            'regions': [],
#            'release-date': '2016-12-15',
#            'released': 2016,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime_noloads',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': False,
#                        'run-times': ['realtime', 'realtime_noloads'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/smr'},
#           {'abbreviation': 'smk',
#            'assets': {'background': {'height': 1024,
#                                      'uri': 'https://www.speedrun.com/themes/smk/background.png',
#                                      'width': 2048},
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/smk/cover-256.png',
#                                       'width': 360},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/smk/cover-128.png',
#                                        'width': 180},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/smk/cover-64.png',
#                                       'width': 90},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/smk/cover-32.png',
#                                      'width': 45},
#                       'foreground': None,
#                       'icon': {'height': 14,
#                                'uri': 'https://www.speedrun.com/themes/smk/favicon.png',
#                                'width': 11},
#                       'logo': {'height': 128,
#                                'uri': 'https://www.speedrun.com/themes/smk/logo.png',
#                                'width': 720},
#                       'trophy-1st': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/smk/1st.png',
#                                      'width': 14},
#                       'trophy-2nd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/smk/2nd.png',
#                                      'width': 14},
#                       'trophy-3rd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/smk/3rd.png',
#                                      'width': 14},
#                       'trophy-4th': None},
#            'created': None,
#            'developers': [],
#            'engines': [],
#            'gametypes': [],
#            'genres': [],
#            'id': 'vo6g8128',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/vo6g8128'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=vo6g8128'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/vo6g8128/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/vo6g8128/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/vo6g8128/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/vo6g8128/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/2qnlpe45'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/vo6g8128/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/vo6g8128/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/vo6g8128/category/l824rmd5'}],
#            'moderators': {'7j426mx1': 'super-moderator'},
#            'names': {'international': 'Super Mario Kart',
#                      'japanese': 'スーパーマリオカート',
#                      'twitch': 'Super Mario Kart'},
#            'platforms': ['83exk6l5',
#                          'nzelreqp',
#                          'v06dr394',
#                          'v06do394',
#                          '7m6ylw9p',
#                          '83exovel'],
#            'publishers': [],
#            'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#            'release-date': '1992-08-27',
#            'released': 1992,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': False,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/smk'},
#           {'abbreviation': 'sml1',
#            'assets': {'background': None,
#                       'cover-large': {'height': 360,
#                                       'uri': 'https://www.speedrun.com/themes/sml1/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 180,
#                                        'uri': 'https://www.speedrun.com/themes/sml1/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 90,
#                                       'uri': 'https://www.speedrun.com/themes/sml1/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 45,
#                                      'uri': 'https://www.speedrun.com/themes/sml1/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/Default/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 32,
#                                'uri': 'https://www.speedrun.com/themes/sml1/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/Default/1st.png',
#                                      'width': 64},
#                       'trophy-2nd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/Default/2nd.png',
#                                      'width': 64},
#                       'trophy-3rd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/Default/3rd.png',
#                                      'width': 64},
#                       'trophy-4th': None},
#            'created': None,
#            'developers': [],
#            'engines': [],
#            'gametypes': [],
#            'genres': [],
#            'id': 'm1mxoj62',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1mxoj62'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=m1mxoj62'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1mxoj62/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1mxoj62/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1mxoj62/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1mxoj62/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/rv7emz49'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1mxoj62/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1mxoj62/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/m1mxoj62/category/02q8py2y'}],
#            'moderators': {'0jmz3zx1': 'super-moderator',
#                           '7j42rwx1': 'super-moderator',
#                           'kjpk14xq': 'super-moderator',
#                           'qxk0r280': 'super-moderator'},
#            'names': {'international': 'Super Mario Land',
#                      'japanese': 'スーパーマリオランド',
#                      'twitch': 'Super Mario Land'},
#            'platforms': ['7g6mx89r', 'n5683oev'],
#            'publishers': [],
#            'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#            'release-date': '1989-01-01',
#            'released': 1989,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/sml1'},
#           {'abbreviation': 'smb1',
#            'assets': {'background': None,
#                       'cover-large': {'height': 360,
#                                       'uri': 'https://www.speedrun.com/themes/smb1/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 180,
#                                        'uri': 'https://www.speedrun.com/themes/smb1/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 90,
#                                       'uri': 'https://www.speedrun.com/themes/smb1/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 45,
#                                      'uri': 'https://www.speedrun.com/themes/smb1/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/Default/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 78,
#                                'uri': 'https://www.speedrun.com/themes/Default/logo.png',
#                                'width': 640},
#                       'trophy-1st': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/Default/1st.png',
#                                      'width': 64},
#                       'trophy-2nd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/Default/2nd.png',
#                                      'width': 64},
#                       'trophy-3rd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/Default/3rd.png',
#                                      'width': 64},
#                       'trophy-4th': None},
#            'created': None,
#            'developers': ['xv6dvx62'],
#            'engines': [],
#            'gametypes': [],
#            'genres': ['qdnqkn8k', 'pm21dr24'],
#            'id': 'om1m3625',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/om1m3625'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=om1m3625'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/om1m3625/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/om1m3625/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/om1m3625/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/om1m3625/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/rv7emz49'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/om1m3625/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/om1m3625/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/om1m3625/category/w20p0zkn'}],
#            'moderators': {'1xy51wv8': 'super-moderator',
#                           '68w5lgq8': 'moderator',
#                           '98r3qn68': 'moderator',
#                           'kj9r2rj4': 'moderator',
#                           'kj9y33ox': 'super-moderator',
#                           'o863w4w8': 'super-moderator',
#                           'qj2n06jk': 'super-moderator',
#                           'qjn1ozw8': 'moderator',
#                           'qjn91qxm': 'super-moderator',
#                           'qjnzw4jm': 'super-moderator',
#                           'qjowye38': 'super-moderator',
#                           'qxk10d2j': 'moderator',
#                           'qxk60398': 'moderator',
#                           'v8l6lwv8': 'moderator',
#                           'y8d3y0mx': 'moderator'},
#            'names': {'international': 'Super Mario Bros.',
#                      'japanese': 'スーパーマリオブラザーズ',
#                      'twitch': 'Super Mario Bros.'},
#            'platforms': ['jm95z9ol',
#                          '83exk6l5',
#                          'nzelreqp',
#                          '3167d6q2',
#                          'v06dk3e4',
#                          '7g6mx89r',
#                          'mr6k409z',
#                          'v06dr394',
#                          'kz9wynep',
#                          '7m6ylw9p',
#                          '83exovel'],
#            'publishers': ['m0rvylrx'],
#            'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#            'release-date': '1985-09-13',
#            'released': 1985,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/smb1'},
#           {'abbreviation': 'supermarioparty',
#            'assets': {'background': {'height': 1080,
#                                      'uri': 'https://www.speedrun.com/themes/supermarioparty/background.png',
#                                      'width': 1920},
#                       'cover-large': {'height': 360,
#                                       'uri': 'https://www.speedrun.com/themes/supermarioparty/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 180,
#                                        'uri': 'https://www.speedrun.com/themes/supermarioparty/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 90,
#                                       'uri': 'https://www.speedrun.com/themes/supermarioparty/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 45,
#                                      'uri': 'https://www.speedrun.com/themes/supermarioparty/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/Default/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 78,
#                                'uri': 'https://www.speedrun.com/themes/Default/logo.png',
#                                'width': 640},
#                       'trophy-1st': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/Default/1st.png',
#                                      'width': 64},
#                       'trophy-2nd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/Default/2nd.png',
#                                      'width': 64},
#                       'trophy-3rd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/Default/3rd.png',
#                                      'width': 64},
#                       'trophy-4th': None},
#            'created': '2018-09-30T01:40:00Z',
#            'developers': [],
#            'engines': [],
#            'gametypes': [],
#            'genres': [],
#            'id': '369p5ml1',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/369p5ml1'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=369p5ml1'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/369p5ml1/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/369p5ml1/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/369p5ml1/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/369p5ml1/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/576m90n2'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/369p5ml1/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/369p5ml1/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/369p5ml1/category/02ql61pk'}],
#            'moderators': {'7j4vyl5j': 'moderator',
#                           '98r2p9wx': 'moderator',
#                           'pj02048w': 'super-moderator',
#                           'qjn9dwxm': 'moderator'},
#            'names': {'international': 'Super Mario Party',
#                      'japanese': None,
#                      'twitch': 'Super Mario Party'},
#            'platforms': ['7m6ylw9p'],
#            'publishers': [],
#            'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#            'release-date': '2018-10-05',
#            'released': 2018,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': False,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/supermarioparty'},
#           {'abbreviation': 'super_mario_dolor',
#            'assets': {'background': None,
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/super_mario_dolor/cover-256.png',
#                                       'width': 360},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/super_mario_dolor/cover-128.png',
#                                        'width': 180},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/super_mario_dolor/cover-64.png',
#                                       'width': 90},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/super_mario_dolor/cover-32.png',
#                                      'width': 45},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/Default/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 78,
#                                'uri': 'https://www.speedrun.com/themes/Default/logo.png',
#                                'width': 640},
#                       'trophy-1st': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/Default/1st.png',
#                                      'width': 64},
#                       'trophy-2nd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/Default/2nd.png',
#                                      'width': 64},
#                       'trophy-3rd': {'height': 64,
#                                      'uri': 'https://www.speedrun.com/themes/Default/3rd.png',
#                                      'width': 64},
#                       'trophy-4th': None},
#            'created': '2018-09-28T06:56:29Z',
#            'developers': [],
#            'engines': [],
#            'gametypes': [],
#            'genres': ['oy5gp5e3'],
#            'id': 'o1y95wr6',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95wr6'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=o1y95wr6'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95wr6/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95wr6/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95wr6/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95wr6/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/xn05xx72'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95wr6/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/o1y95wr6/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/o1y95wr6/category/z27oevzd'}],
#            'moderators': {'dx39qgkx': 'super-moderator',
#                           'kj9o197j': 'super-moderator'},
#            'names': {'international': 'Super Mario Dolor',
#                      'japanese': None,
#                      'twitch': 'Super Mario Dolor'},
#            'platforms': ['8gej2n93'],
#            'publishers': [],
#            'regions': ['pr184lqn',
#                        'e6lxy1dz',
#                        'o316x197',
#                        'mol4z19n',
#                        'p2g50lnk',
#                        'ypl25l47'],
#            'release-date': '2018-05-15',
#            'released': 2018,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/super_mario_dolor'},
#           {'abbreviation': 'smlogic',
#            'assets': {'background': {'height': 1080,
#                                      'uri': 'https://www.speedrun.com/themes/smw/background.png',
#                                      'width': 1920},
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/smlogic/cover-256.png',
#                                       'width': 288},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/smlogic/cover-128.png',
#                                        'width': 144},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/smlogic/cover-64.png',
#                                       'width': 72},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/smlogic/cover-32.png',
# ...
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4j7pde/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/yd4j7pde/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/yd4j7pde/category/vdo4yo62'}],
#            'moderators': {'pj0n70m8': 'super-moderator',
#                           'qjopronx': 'super-moderator',
#                           'v8lyv4jm': 'super-moderator'},
#            'names': {'international': 'Super Mario Run 64',
#                      'japanese': None,
#                      'twitch': 'Super Mario 64'},
#            'platforms': ['w89rwelk', 'nzelreqp', 'v06dr394'],
#            'publishers': [],
#            'regions': [],
#            'release-date': '2016-08-09',
#            'released': 2016,
#            'romhack': True,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/super_mario_run_64'},
#           {'abbreviation': 'smg1',
#            'assets': {'background': {'height': 1080,
#                                      'uri': 'https://www.speedrun.com/themes/smg1/background.png',
#                                      'width': 1920},
#                       'cover-large': {'height': 360,
#                                       'uri': 'https://www.speedrun.com/themes/smg1/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 180,
#                                        'uri': 'https://www.speedrun.com/themes/smg1/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 90,
#                                       'uri': 'https://www.speedrun.com/themes/smg1/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 45,
#                                      'uri': 'https://www.speedrun.com/themes/smg1/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 16,
#                                'uri': 'https://www.speedrun.com/themes/smg1/favicon.png',
#                                'width': 16},
#                       'logo': {'height': 78,
#                                'uri': 'https://www.speedrun.com/themes/Default/logo.png',
#                                'width': 640},
#                       'trophy-1st': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/smg1/1st.png',
#                                      'width': 15},
#                       'trophy-2nd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/smg1/2nd.png',
#                                      'width': 15},
#                       'trophy-3rd': {'height': 16,
#                                      'uri': 'https://www.speedrun.com/themes/smg1/3rd.png',
#                                      'width': 15},
#                       'trophy-4th': None},
#            'created': None,
#            'developers': [],
#            'engines': [],
#            'gametypes': [],
#            'genres': [],
#            'id': 'pd0wg21e',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wg21e'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=pd0wg21e'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wg21e/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wg21e/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wg21e/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wg21e/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/rv7emz49'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wg21e/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wg21e/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/pd0wg21e/category/zd365vdn'}],
#            'moderators': {'68wlrqjg': 'moderator',
#                           '7j4rgow8': 'super-moderator',
#                           '7j4w7lwx': 'super-moderator',
#                           'dx3593qj': 'super-moderator',
#                           'kj9v47x4': 'moderator',
#                           'kjp4wkjq': 'moderator',
#                           'qjo2r086': 'moderator',
#                           'qjopvonx': 'super-moderator',
#                           'qjor2nj6': 'super-moderator',
#                           'zx7yoqx7': 'moderator'},
#            'names': {'international': 'Super Mario Galaxy',
#                      'japanese': 'スーパーマリオギャラクシー',
#                      'twitch': 'Super Mario Galaxy'},
#            'platforms': ['v06dk3e4', 'v06dr394'],
#            'publishers': [],
#            'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197', 'p2g50lnk'],
#            'release-date': '2007-11-01',
#            'released': 2007,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': False,
#                        'require-verification': True,
#                        'require-video': False,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/smg1'},
#           {'abbreviation': 'smrds',
#            'assets': {'background': {'height': 1049,
#                                      'uri': 'https://www.speedrun.com/themes/smrds/background.png',
#                                      'width': 1149},
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/smrds/cover-256.png',
#                                       'width': 360},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/smrds/cover-128.png',
#                                        'width': 180},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/smrds/cover-64.png',
#                                       'width': 90},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/smrds/cover-32.png',
#                                      'width': 45},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/Default/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 32,
#                                'uri': 'https://www.speedrun.com/themes/smrds/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 47,
#                                      'uri': 'https://www.speedrun.com/themes/nsmbds/1st.png',
#                                      'width': 58},
#                       'trophy-2nd': {'height': 40,
#                                      'uri': 'https://www.speedrun.com/themes/nsmbds/2nd.png',
#                                      'width': 45},
#                       'trophy-3rd': {'height': 51,
#                                      'uri': 'https://www.speedrun.com/themes/nsmbds/3rd.png',
#                                      'width': 46},
#                       'trophy-4th': {'height': 50,
#                                      'uri': 'https://www.speedrun.com/themes/nsmbds/4th.png',
#                                      'width': 54}},
#            'created': '2018-07-05T21:43:32Z',
#            'developers': ['1e7rn1z7'],
#            'engines': [],
#            'gametypes': ['v4m291qw'],
#            'genres': ['qdnqkn8k'],
#            'id': 'pd0w7x21',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0w7x21'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=pd0w7x21'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0w7x21/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0w7x21/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0w7x21/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0w7x21/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/5ndldzr7'},
#                      {'rel': 'base-game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/3dxz7p1y'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/3dxz7p1y'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0w7x21/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0w7x21/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/pd0w7x21/category/vdo38l6d'}],
#            'moderators': {'5j52r5zj': 'super-moderator'},
#            'names': {'international': 'Super Mario Run DS',
#                      'japanese': None,
#                      'twitch': 'New Super Mario Bros.'},
#            'platforms': ['7g6m8erk', 'gz9qx60q', 'v06dr394', 'kz9wqn9p'],
#            'publishers': ['gnozd16o'],
#            'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#            'release-date': '2016-10-18',
#            'released': 2016,
#            'romhack': True,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/smrds'},
#           {'abbreviation': 'smbx',
#            'assets': {'background': {'height': 600,
#                                      'uri': 'https://www.speedrun.com/themes/smbx/background.png',
#                                      'width': 800},
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/smbx/cover-256.png',
#                                       'width': 360},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/smbx/cover-128.png',
#                                        'width': 180},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/smbx/cover-64.png',
#                                       'width': 90},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/smbx/cover-32.png',
#                                      'width': 45},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/Default/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 78,
#                                'uri': 'https://www.speedrun.com/themes/Default/logo.png',
#                                'width': 640},
#                       'trophy-1st': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/smbx/1st.png',
#                                      'width': 32},
#                       'trophy-2nd': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/smbx/2nd.png',
#                                      'width': 32},
#                       'trophy-3rd': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/smbx/3rd.png',
#                                      'width': 32},
#                       'trophy-4th': None},
#            'created': '2015-04-01T14:42:51Z',
#            'developers': ['yz8kxxzw',
#                           'nzm8dre0',
#                           'pe1392zo',
#                           '1zkxonej',
#                           '3zy3xp64'],
#            'engines': ['yw3vyr3o'],
#            'gametypes': [],
#            'genres': ['qdnqkn8k', 'pm21dr24'],
#            'id': 'pdv0x91w',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pdv0x91w'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=pdv0x91w'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pdv0x91w/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pdv0x91w/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pdv0x91w/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pdv0x91w/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/xn05xx72'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/y4r230mn'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pdv0x91w/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pdv0x91w/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/pdv0x91w/category/jdzme6kv'}],
#            'moderators': {'68wz2v8g': 'super-moderator',
#                           'v813edlx': 'moderator',
#                           'y8d4l798': 'moderator'},
#            'names': {'international': 'Super Mario Bros. X',
#                      'japanese': None,
#                      'twitch': 'Super Mario Bros. X'},
#            'platforms': ['8gej2n93'],
#            'publishers': [],
#            'regions': [],
#            'release-date': '2009-01-01',
#            'released': 2009,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': False,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/smbx'}],
#  'pagination': {'links': [{'rel': 'next',
#                            'uri': 'https://www.speedrun.com/api/v1/games?name=Super+Mario&offset=20'}],
#                 'max': 20,
#                 'offset': 0,
#                 'size': 20}}

# %%
mario_data = mario_data['data']

# %%
mario_data = mario_data[2]

# %%
pprint(mario_data)
# Out:
# {'abbreviation': 'sm64',
#  'assets': {'background': {'height': 200,
#                            'uri': 'https://www.speedrun.com/themes/sm64/background.png',
#                            'width': 200},
#             'cover-large': {'height': 360,
#                             'uri': 'https://www.speedrun.com/themes/sm64/cover-256.png',
#                             'width': 256},
#             'cover-medium': {'height': 180,
#                              'uri': 'https://www.speedrun.com/themes/sm64/cover-128.png',
#                              'width': 128},
#             'cover-small': {'height': 90,
#                             'uri': 'https://www.speedrun.com/themes/sm64/cover-64.png',
#                             'width': 64},
#             'cover-tiny': {'height': 45,
#                            'uri': 'https://www.speedrun.com/themes/sm64/cover-32.png',
#                            'width': 32},
#             'foreground': None,
#             'icon': {'height': 16,
#                      'uri': 'https://www.speedrun.com/themes/sm64/favicon.png',
#                      'width': 16},
#             'logo': {'height': 32,
#                      'uri': 'https://www.speedrun.com/themes/sm64/logo.png',
#                      'width': 180},
#             'trophy-1st': {'height': 16,
#                            'uri': 'https://www.speedrun.com/themes/sm64/1st.png',
#                            'width': 16},
#             'trophy-2nd': {'height': 16,
#                            'uri': 'https://www.speedrun.com/themes/sm64/2nd.png',
#                            'width': 16},
#             'trophy-3rd': {'height': 16,
#                            'uri': 'https://www.speedrun.com/themes/sm64/3rd.png',
#                            'width': 16},
#             'trophy-4th': None},
#  'created': None,
#  'developers': ['xv6dvx62'],
#  'engines': [],
#  'gametypes': [],
#  'genres': ['jp23ox26'],
#  'id': 'o1y9wo6q',
#  'links': [{'rel': 'self',
#             'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q'},
#            {'rel': 'runs',
#             'uri': 'https://www.speedrun.com/api/v1/runs?game=o1y9wo6q'},
#            {'rel': 'levels',
#             'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q/levels'},
#            {'rel': 'categories',
#             'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q/categories'},
#            {'rel': 'variables',
#             'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q/variables'},
#            {'rel': 'records',
#             'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q/records'},
#            {'rel': 'series',
#             'uri': 'https://www.speedrun.com/api/v1/series/rv7emz49'},
#            {'rel': 'derived-games',
#             'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q/derived-games'},
#            {'rel': 'romhacks',
#             'uri': 'https://www.speedrun.com/api/v1/games/o1y9wo6q/derived-games'},
#            {'rel': 'leaderboard',
#             'uri': 'https://www.speedrun.com/api/v1/leaderboards/o1y9wo6q/category/zdnq4oqd'}],
#  'moderators': {'1xyky4n8': 'moderator',
#                 'e8e6edj0': 'super-moderator',
#                 'e8e9ze2j': 'super-moderator',
#                 'pj0n70m8': 'moderator',
#                 'qjo5lrl8': 'moderator',
#                 'qxk4wo6j': 'moderator',
#                 'v815edqj': 'moderator',
#                 'zx7gkrx7': 'super-moderator',
#                 'zxzvprjq': 'super-moderator'},
#  'names': {'international': 'Super Mario 64',
#            'japanese': 'スーパーマリオ64',
#            'twitch': 'Super Mario 64'},
#  'platforms': ['w89rwelk', 'nzelreqp', 'v06dr394'],
#  'publishers': ['m0rvylrx'],
#  'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#  'release-date': '1996-06-23',
#  'released': 1996,
#  'romhack': False,
#  'ruleset': {'default-time': 'realtime',
#              'emulators-allowed': True,
#              'require-verification': True,
#              'require-video': True,
#              'run-times': ['realtime'],
#              'show-milliseconds': True},
#  'weblink': 'https://www.speedrun.com/sm64'}

# %%
url = "https://www.speedrun.com/api/v1/games?name=Super%20Metroid"

# %%
response = requests.get(url)
print(response.url)
# Out:
# https://www.speedrun.com/api/v1/games?name=Super%20Metroid

# %%
metroid_data = response.json()
pprint(metroid_data)
# Out:
# {'data': [{'abbreviation': 'supermetroid',
#            'assets': {'background': {'height': 2160,
#                                      'uri': 'https://www.speedrun.com/themes/supermetroid/background.png',
#                                      'width': 3840},
#                       'cover-large': {'height': 360,
#                                       'uri': 'https://www.speedrun.com/themes/supermetroid/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 180,
#                                        'uri': 'https://www.speedrun.com/themes/supermetroid/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 90,
#                                       'uri': 'https://www.speedrun.com/themes/supermetroid/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 45,
#                                      'uri': 'https://www.speedrun.com/themes/supermetroid/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/supermetroid/favicon.png',
#                                'width': 62},
#                       'logo': {'height': 32,
#                                'uri': 'https://www.speedrun.com/themes/supermetroid/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/supermetroid/1st.png',
#                                      'width': 15},
#                       'trophy-2nd': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/supermetroid/2nd.png',
#                                      'width': 15},
#                       'trophy-3rd': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/supermetroid/3rd.png',
#                                      'width': 15},
#                       'trophy-4th': None},
#            'created': '2016-11-25T20:23:44Z',
#            'developers': ['1zkdw96j', 'xv6dvx62', 'y4zw106k'],
#            'engines': [],
#            'gametypes': [],
#            'genres': ['7d5owlnw', 'qdnqyk28'],
#            'id': 'm1zoemd0',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=m1zoemd0'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/y4rgq271'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/m1zoemd0/category/9d8v96lk'}],
#            'moderators': {'48g1vv18': 'moderator',
#                           '7j47ee5j': 'moderator',
#                           '7j4rgrl8': 'super-moderator',
#                           'dx3we17j': 'moderator',
#                           'kjpzrl0x': 'moderator',
#                           'qj2ypko8': 'super-moderator',
#                           'qjol3p0j': 'moderator',
#                           'v810merx': 'moderator',
#                           'v810rlxp': 'moderator',
#                           'v8lpmpvj': 'moderator'},
#            'names': {'international': 'Super Metroid',
#                      'japanese': 'スーパーメトロイド',
#                      'twitch': 'Super Metroid'},
#            'platforms': ['83exk6l5',
#                          'nzelreqp',
#                          'v06dr394',
#                          'v06do394',
#                          '7m6ylw9p',
#                          '83exovel'],
#            'publishers': ['m0rvylrx'],
#            'regions': [],
#            'release-date': '1994-03-19',
#            'released': 1994,
#            'romhack': False,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': False,
#                        'require-video': False,
#                        'run-times': ['realtime', 'ingame'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/supermetroid'},
#           {'abbreviation': 'supermetroidhacks',
#            'assets': {'background': {'height': 768,
#                                      'uri': 'https://www.speedrun.com/themes/supermetroidhacks/background.png',
#                                      'width': 768},
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/supermetroidhacks/cover-256.png',
#                                       'width': 288},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/supermetroidhacks/cover-128.png',
#                                        'width': 144},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/supermetroidhacks/cover-64.png',
#                                       'width': 72},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/supermetroidhacks/cover-32.png',
#                                      'width': 36},
#                       'foreground': None,
#                       'icon': {'height': 16,
#                                'uri': 'https://www.speedrun.com/themes/supermetroidhacks/favicon.png',
#                                'width': 16},
#                       'logo': {'height': 78,
#                                'uri': 'https://www.speedrun.com/themes/Default/logo.png',
#                                'width': 640},
#                       'trophy-1st': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/supermetroid/1st.png',
#                                      'width': 15},
#                       'trophy-2nd': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/supermetroid/2nd.png',
#                                      'width': 15},
#                       'trophy-3rd': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/supermetroid/3rd.png',
#                                      'width': 15},
#                       'trophy-4th': None},
#            'created': '2019-01-12T14:41:01Z',
#            'developers': [],
#            'engines': [],
#            'gametypes': ['v4m291qw'],
#            'genres': [],
#            'id': 'pd0wlq21',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wlq21'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=pd0wlq21'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wlq21/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wlq21/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wlq21/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wlq21/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/g450em7q'},
#                      {'rel': 'base-game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wlq21/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/pd0wlq21/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/pd0wlq21/category/wkp3ppw2'}],
#            'moderators': {'0jmpgoj1': 'super-moderator',
#                           '7j4rgrl8': 'moderator',
#                           'kj9dzgwx': 'moderator',
#                           'qxkrm680': 'moderator',
#                           'y8ddom86': 'moderator'},
#            'names': {'international': 'Super Metroid ROM Hacks',
#                      'japanese': None,
#                      'twitch': 'Super Metroid ROM Hacks'},
#            'platforms': ['83exk6l5', 'nzelreqp', 'v06dr394', '83exovel'],
#            'publishers': [],
#            'regions': [],
#            'release-date': '2004-10-14',
#            'released': 2004,
#            'romhack': True,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': False,
#                        'require-video': True,
#                        'run-times': ['realtime', 'ingame'],
#                        'show-milliseconds': False},
#            'weblink': 'https://www.speedrun.com/supermetroidhacks'},
#           {'abbreviation': 'smpb',
#            'assets': {'background': {'height': 800,
#                                      'uri': 'https://www.speedrun.com/themes/smpb/background.png',
#                                      'width': 1280},
#                       'cover-large': {'height': 256,
#                                       'uri': 'https://www.speedrun.com/themes/smpb/cover-256.png',
#                                       'width': 360},
#                       'cover-medium': {'height': 128,
#                                        'uri': 'https://www.speedrun.com/themes/smpb/cover-128.png',
#                                        'width': 180},
#                       'cover-small': {'height': 64,
#                                       'uri': 'https://www.speedrun.com/themes/smpb/cover-64.png',
#                                       'width': 90},
#                       'cover-tiny': {'height': 32,
#                                      'uri': 'https://www.speedrun.com/themes/smpb/cover-32.png',
#                                      'width': 45},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/Default/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 32,
#                                'uri': 'https://www.speedrun.com/themes/smpb/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/smpb/1st.png',
#                                      'width': 15},
#                       'trophy-2nd': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/smpb/2nd.png',
#                                      'width': 15},
#                       'trophy-3rd': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/smpb/3rd.png',
#                                      'width': 15},
#                       'trophy-4th': {'height': 22,
#                                      'uri': 'https://www.speedrun.com/themes/smpb/4th.png',
#                                      'width': 24}},
#            'created': '2015-07-10T04:29:08Z',
#            'developers': ['nelpq762'],
#            'engines': [],
#            'gametypes': ['v4m291qw'],
#            'genres': [],
#            'id': 'y65qy76e',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65qy76e'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=y65qy76e'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65qy76e/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65qy76e/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65qy76e/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65qy76e/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/g450em7q'},
#                      {'rel': 'base-game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65qy76e/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/y65qy76e/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/y65qy76e/category/824xomnd'}],
#            'moderators': {'0jm6de81': 'moderator',
#                           'kj9656vj': 'super-moderator',
#                           'qj2wdwlj': 'moderator',
#                           'qjol3p0j': 'moderator',
#                           'qxkrm680': 'moderator',
#                           'v8l742jm': 'moderator',
#                           'y8ddom86': 'super-moderator'},
#            'names': {'international': 'Super Metroid: Project Base',
#                      'japanese': None,
#                      'twitch': 'Super Metroid Project Base'},
#            'platforms': ['83exk6l5', 'nzelreqp'],
#            'publishers': [],
#            'regions': [],
#            'release-date': '2010-01-01',
#            'released': 2010,
#            'romhack': True,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': True,
#                        'require-video': True,
#                        'run-times': ['realtime', 'ingame'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/smpb'},
#           {'abbreviation': 'super_metroid_category_extensions',
#            'assets': {'background': {'height': 2160,
#                                      'uri': 'https://www.speedrun.com/themes/super_metroid_category_extensions/background.png',
#                                      'width': 3840},
#                       'cover-large': {'height': 360,
#                                       'uri': 'https://www.speedrun.com/themes/super_metroid_category_extensions/cover-256.png',
#                                       'width': 256},
#                       'cover-medium': {'height': 180,
#                                        'uri': 'https://www.speedrun.com/themes/super_metroid_category_extensions/cover-128.png',
#                                        'width': 128},
#                       'cover-small': {'height': 90,
#                                       'uri': 'https://www.speedrun.com/themes/super_metroid_category_extensions/cover-64.png',
#                                       'width': 64},
#                       'cover-tiny': {'height': 45,
#                                      'uri': 'https://www.speedrun.com/themes/super_metroid_category_extensions/cover-32.png',
#                                      'width': 32},
#                       'foreground': None,
#                       'icon': {'height': 64,
#                                'uri': 'https://www.speedrun.com/themes/super_metroid_category_extensions/favicon.png',
#                                'width': 64},
#                       'logo': {'height': 32,
#                                'uri': 'https://www.speedrun.com/themes/super_metroid_category_extensions/logo.png',
#                                'width': 180},
#                       'trophy-1st': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/super_metroid_category_extensions/1st.png',
#                                      'width': 15},
#                       'trophy-2nd': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/super_metroid_category_extensions/2nd.png',
#                                      'width': 15},
#                       'trophy-3rd': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/super_metroid_category_extensions/3rd.png',
#                                      'width': 15},
#                       'trophy-4th': {'height': 15,
#                                      'uri': 'https://www.speedrun.com/themes/super_metroid_category_extensions/4th.png',
#                                      'width': 15}},
#            'created': '2017-11-20T04:20:55Z',
#            'developers': ['jev0k5zk'],
#            'engines': [],
#            'gametypes': ['53no817x'],
#            'genres': ['9rnvvrnq'],
#            'id': '76rxw8l6',
#            'links': [{'rel': 'self',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxw8l6'},
#                      {'rel': 'runs',
#                       'uri': 'https://www.speedrun.com/api/v1/runs?game=76rxw8l6'},
#                      {'rel': 'levels',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxw8l6/levels'},
#                      {'rel': 'categories',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxw8l6/categories'},
#                      {'rel': 'variables',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxw8l6/variables'},
#                      {'rel': 'records',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxw8l6/records'},
#                      {'rel': 'series',
#                       'uri': 'https://www.speedrun.com/api/v1/series/y4rgq271'},
#                      {'rel': 'base-game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0'},
#                      {'rel': 'game',
#                       'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0'},
#                      {'rel': 'derived-games',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxw8l6/derived-games'},
#                      {'rel': 'romhacks',
#                       'uri': 'https://www.speedrun.com/api/v1/games/76rxw8l6/derived-games'},
#                      {'rel': 'leaderboard',
#                       'uri': 'https://www.speedrun.com/api/v1/leaderboards/76rxw8l6/category/02qo3mjk'}],
#            'moderators': {'0jmyywoj': 'super-moderator',
#                           '7j47ee5j': 'moderator',
#                           '7j4qve5x': 'super-moderator',
#                           'dx3we17j': 'super-moderator',
#                           'qj2wdwlj': 'super-moderator',
#                           'qjol3p0j': 'moderator',
#                           'qxkm1n6j': 'super-moderator',
#                           'v810merx': 'super-moderator'},
#            'names': {'international': 'Super Metroid Category Extensions',
#                      'japanese': 'スーパーメトロイド',
#                      'twitch': 'Super Metroid'},
#            'platforms': ['83exk6l5',
#                          'nzelreqp',
#                          '7g6mx89r',
#                          'v06dr394',
#                          '83exovel'],
#            'publishers': ['m0rvylrx'],
#            'regions': [],
#            'release-date': '1994-03-19',
#            'released': 1994,
#            'romhack': True,
#            'ruleset': {'default-time': 'realtime',
#                        'emulators-allowed': True,
#                        'require-verification': False,
#                        'require-video': True,
#                        'run-times': ['realtime'],
#                        'show-milliseconds': True},
#            'weblink': 'https://www.speedrun.com/super_metroid_category_extensions'}],
#  'pagination': {'links': [], 'max': 20, 'offset': 0, 'size': 4}}

# %%
metroid_data = metroid_data['data']

# %%
metroid_data = metroid_data[0]

# %%
pprint(metroid_data)
# Out:
# {'abbreviation': 'supermetroid',
#  'assets': {'background': {'height': 2160,
#                            'uri': 'https://www.speedrun.com/themes/supermetroid/background.png',
#                            'width': 3840},
#             'cover-large': {'height': 360,
#                             'uri': 'https://www.speedrun.com/themes/supermetroid/cover-256.png',
#                             'width': 256},
#             'cover-medium': {'height': 180,
#                              'uri': 'https://www.speedrun.com/themes/supermetroid/cover-128.png',
#                              'width': 128},
#             'cover-small': {'height': 90,
#                             'uri': 'https://www.speedrun.com/themes/supermetroid/cover-64.png',
#                             'width': 64},
#             'cover-tiny': {'height': 45,
#                            'uri': 'https://www.speedrun.com/themes/supermetroid/cover-32.png',
#                            'width': 32},
#             'foreground': None,
#             'icon': {'height': 64,
#                      'uri': 'https://www.speedrun.com/themes/supermetroid/favicon.png',
#                      'width': 62},
#             'logo': {'height': 32,
#                      'uri': 'https://www.speedrun.com/themes/supermetroid/logo.png',
#                      'width': 180},
#             'trophy-1st': {'height': 15,
#                            'uri': 'https://www.speedrun.com/themes/supermetroid/1st.png',
#                            'width': 15},
#             'trophy-2nd': {'height': 15,
#                            'uri': 'https://www.speedrun.com/themes/supermetroid/2nd.png',
#                            'width': 15},
#             'trophy-3rd': {'height': 15,
#                            'uri': 'https://www.speedrun.com/themes/supermetroid/3rd.png',
#                            'width': 15},
#             'trophy-4th': None},
#  'created': '2016-11-25T20:23:44Z',
#  'developers': ['1zkdw96j', 'xv6dvx62', 'y4zw106k'],
#  'engines': [],
#  'gametypes': [],
#  'genres': ['7d5owlnw', 'qdnqyk28'],
#  'id': 'm1zoemd0',
#  'links': [{'rel': 'self',
#             'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0'},
#            {'rel': 'runs',
#             'uri': 'https://www.speedrun.com/api/v1/runs?game=m1zoemd0'},
#            {'rel': 'levels',
#             'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0/levels'},
#            {'rel': 'categories',
#             'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0/categories'},
#            {'rel': 'variables',
#             'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0/variables'},
#            {'rel': 'records',
#             'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0/records'},
#            {'rel': 'series',
#             'uri': 'https://www.speedrun.com/api/v1/series/y4rgq271'},
#            {'rel': 'derived-games',
#             'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0/derived-games'},
#            {'rel': 'romhacks',
#             'uri': 'https://www.speedrun.com/api/v1/games/m1zoemd0/derived-games'},
#            {'rel': 'leaderboard',
#             'uri': 'https://www.speedrun.com/api/v1/leaderboards/m1zoemd0/category/9d8v96lk'}],
#  'moderators': {'48g1vv18': 'moderator',
#                 '7j47ee5j': 'moderator',
#                 '7j4rgrl8': 'super-moderator',
#                 'dx3we17j': 'moderator',
#                 'kjpzrl0x': 'moderator',
#                 'qj2ypko8': 'super-moderator',
#                 'qjol3p0j': 'moderator',
#                 'v810merx': 'moderator',
#                 'v810rlxp': 'moderator',
#                 'v8lpmpvj': 'moderator'},
#  'names': {'international': 'Super Metroid',
#            'japanese': 'スーパーメトロイド',
#            'twitch': 'Super Metroid'},
#  'platforms': ['83exk6l5',
#                'nzelreqp',
#                'v06dr394',
#                'v06do394',
#                '7m6ylw9p',
#                '83exovel'],
#  'publishers': ['m0rvylrx'],
#  'regions': [],
#  'release-date': '1994-03-19',
#  'released': 1994,
#  'romhack': False,
#  'ruleset': {'default-time': 'realtime',
#              'emulators-allowed': True,
#              'require-verification': False,
#              'require-video': False,
#              'run-times': ['realtime', 'ingame'],
#              'show-milliseconds': True},
#  'weblink': 'https://www.speedrun.com/supermetroid'}
